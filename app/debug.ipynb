# %%
import pandas as pd

uploads = pd.read_csv('data/opensnp_uploads.csv')

# %%
uploads['time'] = pd.to_datetime(uploads['time'], format='%d.%m.%Y %H:%M')

# %%
uploads['time'].value_counts().sort_index()

time_points = uploads['time'].dt.to_period('M').value_counts().sort_index()
time_points.index = time_points.index.to_timestamp()
time_points.plot()
# # plot the number of total uploads by month
# uploads['time'].dt.to_period('M').value_counts().sort_index().cumsum().plot()
# Out:
# <AxesSubplot: xlabel='time'>

# %%
time_points.index
# Out:
# DatetimeIndex(['2011-09-01', '2011-10-01', '2011-11-01', '2011-12-01',
#                '2012-01-01', '2012-02-01', '2012-03-01', '2012-04-01',
#                '2012-05-01', '2012-06-01',
#                ...
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01'],
#               dtype='datetime64[ns]', name='time', length=155, freq=None)
